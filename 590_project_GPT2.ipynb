# %% [markdown]
# # Prepare Dataset

# %%
# !wget https://rajpurkar.github.io/SQuAD-explorer/dataset/train-v2.0.json
# !wget https://rajpurkar.github.io/SQuAD-explorer/dataset/dev-v2.0.json
# Out:
# --2020-12-16 18:02:19--  https://rajpurkar.github.io/SQuAD-explorer/dataset/train-v2.0.json
# Resolving rajpurkar.github.io (rajpurkar.github.io)... 185.199.108.153, 185.199.109.153, 185.199.110.153, ...
# Connecting to rajpurkar.github.io (rajpurkar.github.io)|185.199.108.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 42123633 (40M) [application/json]
# Saving to: ‘train-v2.0.json’
#
# train-v2.0.json     100%[===================>]  40.17M  66.4MB/s    in 0.6s
#
# 2020-12-16 18:02:24 (66.4 MB/s) - ‘train-v2.0.json’ saved [42123633/42123633]
#
# --2020-12-16 18:02:24--  https://rajpurkar.github.io/SQuAD-explorer/dataset/dev-v2.0.json
# Resolving rajpurkar.github.io (rajpurkar.github.io)... 185.199.109.153, 185.199.111.153, 185.199.110.153, ...
# Connecting to rajpurkar.github.io (rajpurkar.github.io)|185.199.109.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4370528 (4.2M) [application/json]
# Saving to: ‘dev-v2.0.json’
#
# dev-v2.0.json       100%[===================>]   4.17M  21.7MB/s    in 0.2s
#
# 2020-12-16 18:02:25 (21.7 MB/s) - ‘dev-v2.0.json’ saved [4370528/4370528]

# %%
# %tensorflow_version 1.x
import tensorflow as tf
# !pip install -q gpt-2-simple
import gpt_2_simple as gpt2
from datetime import datetime
from google.colab import files

import json
import random
import numpy as np
from time import time
from tqdm import tqdm
# Out:
# TensorFlow 1.x selected.
#   Building wheel for gpt-2-simple (setup.py) ... done
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
# Preprocess training set
c, q, a, e = "<|startoftext|>\n[CONTEXT]: ", "\n[QUESTION]:", "\n[ANSWER]:", "\n<|endoftext|>\n"

def preprocess_paragraphs(data):
  pars_data = c + data['context']
  qas_list = data['qas']
  random.shuffle(qas_list) # random shuffle quesitons
  for qas in qas_list:
    pars_data += q + qas['question']
    try:
      if qas['is_impossible']:
        pars_data += a + 'unanswerable'
      else:
        pars_data += a + qas['answers'][0]['text']
    except:
      print(qas)
      raise
  pars_data += e
  return pars_data

def extract_article(data):
  article_data = ''
  paras_list = data['paragraphs']
  random.shuffle(paras_list) # random shuffle paragraphs
  for pars in paras_list:
    article_data += preprocess_paragraphs(pars)
  return article_data

def preprocess_train(data):
  dataset = ''
  article_list = data['data']
  random.shuffle(article_list)
  for article in article_list:
    dataset += extract_article(article)
  return dataset

# %%
with open('train-v2.0.json') as f:
  train_data = json.load(f)
  
train_dataset = preprocess_train(train_data)

# %%
print(f'Length of the corpus: {len(train_dataset)}')
# Out:
# Length of the corpus: 27563659

# %% [markdown]
# # Training set explanation
#
# ### Since GPT-2 is trained using unsupervised learning, the training set is just a really long python string, or namely corpus, without any label. GPT-2 learns to generate text given the warm-up text.
#
# ### So how can we make the autoregression model to answer a question? We need some special token to indicate what we expect GPT-2 to do next. Here is an example:

# %%
print(train_dataset[:3000])
# Out:
# <|startoftext|>
# [CONTEXT]: Philadelphia artists have had a prominent national role in popular music. In the 1970s, Philadelphia soul influenced the music of that and later eras. On July 13, 1985, Philadelphia hosted the American end of the Live Aid concert at John F. Kennedy Stadium. The city reprised this role for the Live 8 concert, bringing some 700,000 people to the Ben Franklin Parkway on July 2, 2005. Philadelphia is home to the world-renowned Philadelphia Boys Choir & Chorale, which has performed its music all over the world. Dr. Robert G. Hamilton, founder of the choir, is a notable native Philadelphian. The Philly Pops is another famous Philadelphia music group. The city has played a major role in the development and support of American rock music and rap music. Hip-hop/Rap artists such as The Roots, DJ Jazzy Jeff & The Fresh Prince, The Goats, Freeway, Schoolly D, Eve, and Lisa "Left Eye" Lopes hail from the city.
# [QUESTION]:What concert did Philly host on July13th, 1985?
# [ANSWER]:Live Aid
# [QUESTION]:What is the name of the stadium that held Live Aid?
# [ANSWER]:John F. Kennedy Stadium
# [QUESTION]:Name a type of music from the 70's that influenced the nation?
# [ANSWER]:Philadelphia soul
# [QUESTION]:Name a hip/hop artist from the city?
# [ANSWER]:The Roots, DJ Jazzy Jeff & The Fresh Prince, The Goats, Freeway, Schoolly D, Eve, and Lisa "Left Eye" Lopes
# <|endoftext|>
# <|startoftext|>
# [CONTEXT]: For much of Philadelphia's history, the typical home has been the row house. The row house was introduced to the United States via Philadelphia in the early 19th century and, for a time, row houses built elsewhere in the United States were known as "Philadelphia rows". A variety of row houses are found throughout the city, from Victorian-style homes in North Philadelphia to twin row houses in West Philadelphia. While newer homes are scattered throughout the city, much of the housing is from the early 20th century or older. The great age of the homes has created numerous problems, including blight and vacant lots in many parts of the city, while other neighborhoods such as Society Hill, which has the largest concentration of 18th-century architecture in the United States, have been rehabilitated and gentrified.
# [QUESTION]:Name a type of row house in the city?
# [ANSWER]:Victorian-style homes in North Philadelphia to twin row houses in West Philadelphia
# [QUESTION]:What are row houses called outside of Philadelphia?
# [ANSWER]:Philadelphia rows
# [QUESTION]:What is the dominant type of house in Philadelphia?
# [ANSWER]:row house
# [QUESTION]:How old is most of the housing in Philadelphia?
# [ANSWER]:early 20th century or older
# [QUESTION]:Which neighborhood has the oldest housing in America?
# [ANSWER]:Society Hill
# <|endoftext|>
# <|startoftext|>
# [CONTEXT]: By the 20th century, Philadelphia had become known as "corrupt and contented", with a complacent population and an entrenched Republican political machine. The first major reform came in 1917 when outrage over the election

# %%
f = open("squad2_dataset.txt","w")
f.write(train_dataset)
f.close()

# %%
file_name = "squad2_dataset.txt"

# %% [markdown]
# ### In the raw dataset, unanwerable questions are always after answerable ones. This undesired pattern maybe learned by the GPT-2 model, leading to overfitting. So we randomly shuffle the questions to mitigate this problem.
#
#
# ### This also shows GPT-2 model has a strong capacity to fit many kinds of long-sequence patterns, so if the training text if uncarefully preprocessed, it's easy to overfitting.

# %%
# preprocess test set
def read_file(file_name):
  with open(file_name) as f:
    data = json.load(f)
  contexts = list()
  questions = list()
  answers = list()
    
  for group in data['data']:
      for passage in group['paragraphs']:
          context = passage['context']
          for qa in passage['qas']:
              question = qa['question']
              an = []
              if(qa['is_impossible']):
                an.append('unanswerable')
              else:
                for answer in qa['answers']:
                  an.append(answer['text'])
              contexts.append(context)
              questions.append(question)
              answers.append(an)

  return contexts, questions, answers

with open('dev-v2.0.json') as f:
  dev_data = json.load(f)

dev_contexts, dev_questions, dev_answers = read_file('dev-v2.0.json')

# %% [markdown]
# ## An input example at prediction time. After finetuning, the GPT-2 model is expected to give the answer after the '[ANSWER]:' token.

# %%
print(c + dev_contexts[0] + q + dev_questions[0] + a)
# Out:
# <|startoftext|>
# [CONTEXT]: The Normans (Norman: Nourmands; French: Normands; Latin: Normanni) were the people who in the 10th and 11th centuries gave their name to Normandy, a region in France. They were descended from Norse ("Norman" comes from "Norseman") raiders and pirates from Denmark, Iceland and Norway who, under their leader Rollo, agreed to swear fealty to King Charles III of West Francia. Through generations of assimilation and mixing with the native Frankish and Roman-Gaulish populations, their descendants would gradually merge with the Carolingian-based cultures of West Francia. The distinct cultural and ethnic identity of the Normans emerged initially in the first half of the 10th century, and it continued to evolve over the succeeding centuries.
# [QUESTION]:In what country is Normandy located?
# [ANSWER]:

# %%
# !nvidia-smi
# Out:
# Wed Dec 16 18:14:44 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.45.01    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    23W / 300W |      0MiB / 16130MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Downloading GPT-2
#
# There are three released sizes of GPT-2:
#
# * `124M` (default): the "small" model, 500MB on disk.
# * `355M`: the "medium" model, 1.5GB on disk.
# * `774M`: the "large" model,
# * `1558M`: the "extra large",
#
# Larger models have more knowledge, but take longer to finetune and longer to generate text.

# %%
gpt2.download_gpt2(model_name="355M")
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 208Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 73.1Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 289Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 1.42Git [00:16, 84.7Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 184Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 94.6Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 151Mit/s]

# %%
# gpt2.mount_gdrive()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### The training time for a medium model on our dataset takes 4.5 hour (30,000 steps) using Tesla V100 (fastest on colab, need colab pro). It will take much longer using other GPU.

# %%
# %%time
sess = gpt2.start_tf_sess()

gpt2.finetune(sess,
              dataset=file_name,
              model_name='355M',
              steps=30000,
              restore_from='fresh',
              run_name='QA_m_30k_random',
              print_every=100,
              sample_every=2000,
              save_every=2000)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/sample.py:17: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/memory_saving_gradients.py:62: get_backward_walk_ops (from tensorflow.contrib.graph_editor.select) is deprecated and will be removed after 2019-06-06.
# Instructions for updating:
# Please use tensorflow.python.ops.op_selector.get_backward_walk_ops.
# Loading checkpoint models/355M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/355M/model.ckpt
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [00:32<00:00, 32.37s/it]
# dataset has 6756495 tokens
# Training...
# [100 | 62.37] loss=1.76 avg=1.76
# [200 | 114.60] loss=1.65 avg=1.71
# [300 | 166.66] loss=1.77 avg=1.73
# [400 | 218.80] loss=1.84 avg=1.76
# [500 | 270.97] loss=1.92 avg=1.79
# [600 | 323.10] loss=2.05 avg=1.83
# [700 | 375.19] loss=1.43 avg=1.78
# [800 | 427.77] loss=2.18 avg=1.83
# [900 | 480.00] loss=1.90 avg=1.84
# [1000 | 532.11] loss=2.12 avg=1.86
# [1100 | 584.27] loss=2.19 avg=1.90
# [1200 | 636.44] loss=2.43 avg=1.94
# [1300 | 688.52] loss=1.62 avg=1.92
# [1400 | 740.58] loss=1.98 avg=1.92
# [1500 | 792.75] loss=1.41 avg=1.88
# [1600 | 844.87] loss=1.76 avg=1.88
# [1700 | 897.04] loss=1.64 avg=1.86
# [1800 | 949.21] loss=2.33 avg=1.89
# [1900 | 1001.34] loss=2.27 avg=1.91
# [2000 | 1053.87] loss=1.70 avg=1.90
# Saving checkpoint/QA_m_70k_random/model-2000
# ======== SAMPLE 1 ========
#  to the United States, is known as one of the most technologically advanced cities on the planet, and was also the capital of the country the United States during the Industrial Revolution and the American Revolution.
# [QUESTION]:Where is the United States most popularly known for its development?
# [ANSWER]:The United States
# [QUESTION]:Where in the world does the most people travel to eat, work, and play?
# [ANSWER]:The US
# [QUESTION]:Which city is considered the preeminent location for its development?
# [ANSWER]:Chicago
# [QUESTION]:Which city is one of the few that has been known for its development since the 18th century?
# [ANSWER]:unanswerable
# [QUESTION]:What is the city known as among American cities, and has a population of the greatest total since the 1720s?
# [ANSWER]:unanswerable
# [QUESTION]:Who has ruled most of the world with less wealth?
# [ANSWER]:unanswerable
# [QUESTION]:What is the name which was used for one of the most successful cities to be founded?
# [ANSWER]:Chicago
# <|endoftext|>
# <|startoftext|>
# [CONTEXT]: Some parts of the United States include the District of Columbia, which has a population of less than 100,000 as of 2011, according to a 2012 U.S. Census report. As of 2013 population of metropolitan area populations in the U.S. ranged from 4,743,812 (0.8%) to 12,049,723 (16.3%).
# [QUESTION]:What percentage of the census population lived outside of the United States in 2011?
# [ANSWER]:unanswerable
# [QUESTION]:What metropolitan area's population is estimated to be less than 50,000 by 2014?
# [ANSWER]:unanswerable
# [QUESTION]:Which city has a population of less than 100,000 that was used in 2011?
# [ANSWER]:unanswerable
# [QUESTION]:What percent of the population living outside the United States did in 2011?
# [ANSWER]:5,700
# [QUESTION]:What did the U.S. Census Bureau say in 2008 about the total population of metropolitan areas in the U.S.?
# [ANSWER]:0.8%
# [QUESTION]:How much were residents in the U.S. from 2011-2015?
# [ANSWER]:100,000
# [QUESTION]:How many people lived in the United States in 2011?
# [ANSWER]:100,000
# [QUESTION]:How many people live in the metro area?
# [ANSWER]:500,000
# [QUESTION]:In other words what percent of the population lived outside of the United States in 2012?
# [ANSWER]:unanswerable
# [QUESTION]:What percent of the U.S. population lived in Chicago in 2012?
# [ANSWER]:0.8%
# <|endoftext|>
# <|startoftext|>
# [CONTEXT]: Many American cities and towns are located in regions of low population density, such as lower-density cities, rural areas and suburbs. San Francisco is the U.S. city with the largest urban area by area. In the United States, cities with populations over 100,000 have generally been developed as high-rise housing developments. The city of Los Angeles, California, with a population over 100,000, was the United States' largest city when it adopted a policy in 2001 to increase the number of houses to 80,000 from 65,000, in exchange for which the city received federal funds for construction of a 40-plus-story highrise. The housing boom is continuing elsewhere in the United States. In 2015 a new wave of high-, medium-, and lowrise housing projects began to start construction in Austin, Texas. The city started construction on the former Sears store at the intersection of S. Lamar and Eastman Avenues on June 6, 2015, and the first eight-story highrise was completed in the spring of 2016.
# [QUESTION]:What city is considered the most populous city in the United States?
# [ANSWER]:Los Angeles
# [QUESTION]:How many floors of buildings were added in the first ten years of lowrise housing projects?
# [ANSWER]:16,000
# [QUESTION]:How many units were added to the Sears store in the past ten years?
# [ANSWER]:80,000
# [QUESTION]:What area is considered the most densly populated U.S. city on the basis of density?
# [ANSWER]:unanswerable
# [QUESTION]:What is the name of the former Sears store formerly known as?
# [ANSWER]:the Sears Store
# [QUESTION]:How many floors is there in the United States city of Austin?
# [ANSWER]:
#
# [2100 | 1134.71] loss=1.55 avg=1.88
# [2200 | 1186.77] loss=1.67 avg=1.87
# [2300 | 1238.93] loss=1.49 avg=1.85
# [2400 | 1291.00] loss=2.10 avg=1.86
# [2500 | 1343.02] loss=1.67 avg=1.85
# [2600 | 1394.97] loss=1.61 avg=1.84
# [2700 | 1447.07] loss=1.89 avg=1.85
# [2800 | 1499.09] loss=1.81 avg=1.84
# [2900 | 1551.28] loss=1.56 avg=1.83
# [3000 | 1603.55] loss=2.16 avg=1.85
# [3100 | 1655.80] loss=2.22 avg=1.86
# [3200 | 1707.98] loss=1.28 avg=1.84
# [3300 | 1760.11] loss=1.91 avg=1.84
# [3400 | 1812.21] loss=1.63 avg=1.83
# [3500 | 1864.38] loss=1.81 avg=1.83
# [3600 | 1916.43] loss=1.95 avg=1.84
# [3700 | 1968.47] loss=1.76 avg=1.83
# [3800 | 2020.57] loss=1.70 avg=1.83
# [3900 | 2072.69] loss=1.52 avg=1.82
# [4000 | 2124.78] loss=1.39 avg=1.81
# Saving checkpoint/QA_m_70k_random/model-4000
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# ======== SAMPLE 1 ========
#  has to be the purpose. The first "universal" use of the "God" name is Greek (Grecian) "gros", literally "one", "one substance" or "one substance", and in the same breath. Greek culture and religion are often characterized as that of a Greek "grist", a term used to describe the life of the Greek people by their people, the traditions they live by and their spiritual ideals.[citation needed] It is also the term given to describe those Greek elements of which the Greek cultures are made.
# [QUESTION]:What does gros not mean?
# [ANSWER]:unanswerable
# [QUESTION]:An example of a Greek culture is what?
# [ANSWER]:Greek culture
# [QUESTION]:What does gros mean?
# [ANSWER]:one substance
# [QUESTION]:What is some words which are used to describe Greek culture and religion?
# [ANSWER]:"grist",
# [QUESTION]:Who said that the Grecian Greeks used god as a god?
# [ANSWER]:Greek culture and religion are
# [QUESTION]:What is not a Greek culture?
# [ANSWER]:unanswerable
# [QUESTION]:The words Gros and Gris are not used in the same way in what language?
# [ANSWER]:unanswerable
# [QUESTION]:The Greeks are also called what by others?
# [ANSWER]:gros",
# <|endoftext|>
# <|startoftext|>
# [CONTEXT]: Greek-derived words are often more restricted than Greek words. An example is the word ὑάχω, which can only be used to mean a person in possession or control, i.e., someone who is in possession of property. More usually, these words are used to mean persons in possession of wealth, i.e., those who are able to exert control over or influence the affairs of their fellow-men.
# [QUESTION]: What is more restricted than Greek words?
# [ANSWER]:Greek-derived words
# [QUESTION]:What is not an example of a Greek-derived word?
# [ANSWER]:unanswerable
# [QUESTION]:How is Greek-derived words generally restricted?
# [ANSWER]:Greek-derived words are often more restricted than Greek words
# [QUESTION]:How often are Greek-derived words mostly used in English?
# [ANSWER]:unanswerable
# [QUESTION]:What is more restricted than Greek words?
# [ANSWER]:unanswerable
# [QUESTION]:What is not an example of a Greek-derived word?
# [ANSWER]:unanswerable
# [QUESTION]:How is Greek-derived words typically used in Greek life?
# [ANSWER]:unanswerable
# <|endoftext|>
# <|startoftext|>
# [CONTEXT]: The term "Greek-derived language" may refer to the languages that were influenced by those languages of the Western languages and that were then influenced by those languages of the Eastern world. The term was often used in the 19th and 20th centuries, as a term for non-Greek languages which were considered to have descended from ancient Greek, e.g., Indo-European languages. It was first proposed as a part of the study of ancient Greek, as it was thought to be that the ancient Greeks were influenced by Indo-European languages in the same way that the Greeks apparently descend from ancient Indo-European languages.[citation needed] Some scholars believe that Greek was influenced by a variety of languages.[citation needed] In particular, one of the theories, postulated by Vasily Smetana for the origin of Greek, proposes that the Greeks descended from languages of the Eastern World, and that Greek is descended from Greek languages that, according to Smetana's theory, descended from Indo-European languages.
# [QUESTION]:What do some say the Greek language descended from?
# [ANSWER]:unanswerable
# [QUESTION]:What does non-Greek languages not come into contact with?
# [ANSWER]:unanswerable
# [QUESTION]:What language did not come into contact with Greek languages?
# [ANSWER]:unanswerable
# [QUESTION]:What was used for studying the ancient languages, and as a term for what ancient language?
# [ANSWER]:unanswerable
# [QUESTION]:What does "Greek-derived language" refer to?
# [ANSWER]:unanswerable
# [QUESTION]:Who was one of the theory's that the Greeks descended from languages of the East world?
# [ANSWER]:unanswerable
# [QUESTION]:Who believed that the ancient Greeks were influenced by Indo-European languages?
# [ANSWER]:Vasily Smetana
# [QUESTION]:Who proposed that the ancient Greeks were influenced by Indo-European languages?
# [ANSWER]:Vasily
#
# [4100 | 2203.12] loss=1.62 avg=1.80
# [4200 | 2255.15] loss=1.95 avg=1.81
# [4300 | 2307.17] loss=1.90 avg=1.81
# [4400 | 2359.18] loss=2.07 avg=1.82
# [4500 | 2411.23] loss=1.89 avg=1.82
# [4600 | 2463.29] loss=2.01 avg=1.82
# [4700 | 2515.31] loss=2.23 avg=1.83
# [4800 | 2567.37] loss=2.39 avg=1.85
# [4900 | 2619.39] loss=1.84 avg=1.85
# [5000 | 2671.43] loss=1.32 avg=1.84
# [5100 | 2723.59] loss=1.85 avg=1.84
# [5200 | 2775.80] loss=2.06 avg=1.84
# [5300 | 2827.98] loss=1.41 avg=1.83
# [5400 | 2880.26] loss=1.21 avg=1.82
# [5500 | 2932.32] loss=1.35 avg=1.81
# [5600 | 2984.39] loss=1.92 avg=1.81
# [5700 | 3036.50] loss=1.08 avg=1.79
# [5800 | 3088.61] loss=1.31 avg=1.78
# [5900 | 3140.69] loss=1.74 avg=1.78
# [6000 | 3192.73] loss=1.45 avg=1.77
# Saving checkpoint/QA_m_70k_random/model-6000
# ======== SAMPLE 1 ========
#  secretary. In recent years, the Supreme Court has frequently affirmed the right to the vote for all citizens of the United States regardless of race or social status. In 2006, for example, the Supreme Court held that the right to vote for the American Indian and Alaska Native, and other Native Americans, is the same as the right to voting for white citizens, which is currently the only minority vote. The same right is still required, however, to be eligible to vote for one of the two seats available to a racial or ethnic minority; in 2008, an analysis found only 32 racial or ethnic minority seats. The right to vote for someone who is not a white citizen has been granted and continues to be protected by federal and state law. In addition to voting rights, the Constitution protects the right to keep and bear arms, and to purchase and possess firearm ammunition.
# [QUESTION]:In what year did the Court decide to establish racial minorities in voting for seats on the House?
# [ANSWER]:2006
# [QUESTION]:In what year did it found that the Constitution protected the right to vote for those of certain races of the U.S.?
# [ANSWER]:2008
# [QUESTION]:There is currently only one seat available for a racial or ethnic minority.
# [ANSWER]:reserved
# [QUESTION]:In 2008 what seat was not reserved?
# [ANSWER]:reserved
# [QUESTION]:In the Senate a seat is known as what?
# [ANSWER]:unenrolled
# [QUESTION]:Where can certain races of the U.S. be enrolled in voting?
# [ANSWER]:many more races
# [QUESTION]:What was the seat of a member of the House, held only by women, used as an open seat by women?
# [ANSWER]:unanswerable
# [QUESTION]:What do the Constitution protect when it comes to minorities?
# [ANSWER]:the right to keep and bear arms
# [QUESTION]:In what year did the U.S. Supreme Court make affirmative action mandatory?
# [ANSWER]:unanswerable
# [QUESTION]:A seat has not been made available for affirmative action because of the low population.
# [ANSWER]:unanswerable
# [QUESTION]:How many seats are reserved for members of a House committee?
# [ANSWER]:unanswerable
# <|endoftext|>
# <|startoftext|>
# [CONTEXT]: The U.S. Census Bureau estimated that in 2000, 40% of all African Americans (including those in the former Confederacy and those of mixed-race ancestry) lived in the state of Alabama, the largest percentage being the Black adult population. Among the non-Hispanic white non-Hispanic group, 8.3% were of the Black adult population while 6.9% were of mixed race ancestry. These non-Hispanic White Non-Hispanic (SW-COP) population includes those who self-identify as White Christians, Evangelical Protestants, Latter-day Saints, and Protestants. About 4% of White Americans live in Alabama.[clarification needed]
# [QUESTION]:How many non-Hispanic white non-Hispanic adults were of the Black adult population in 2000?
# [ANSWER]:unanswerable
# [QUESTION]:About how many non-Hispanic white non-Hispanic adults lived in the African American community in 2000?
# [ANSWER]:some 20%
# [QUESTION]:What percentage of non-Hispanic non-white adult Alabama residents were of the black adult population?
# [ANSWER]:unanswerable
# [QUESTION]:What percentage of African Americans in Alabama were of mixed race ancestry?
# [ANSWER]:40%
# [QUESTION]:Of all Southern states, what percentage held the largest percentage of African Americans?
# [ANSWER]:unanswerable
# [QUESTION]:Approximately what percentage of non-Hispanic white non-Hispanic adults are of mixed race ancestry?
# [ANSWER]:8.3%
# [QUESTION]:About 5% of White Americans live in Alabama.
# [ANSWER]:unanswerable
# <|endoftext|>
# <|startoftext|>
# [CONTEXT]: In 2002, Republicans took control of the General Assembly for the first time in more than 30 years with one more seat up for election. Republicans, led by Majority Leader Steve Bannon, won control of the House by over 100 seats and took the governor's office, winning another majority. The GOP also took control of the Alabama Supreme Court, which was confirmed by a Republican-dominated Senate in early 2013. Republican leaders have vowed to continue their successful push to overturn the recent court decisions while Democrats have called for the state to join the U.S. Supreme Court in the case of Fisher v. Texas.
# [QUESTION]:Who was the Republican majority leader at that time?
# [ANSWER]:Steve Bannon
# [QUESTION]:When did Republicans take control of the state legislature?
#
#
# [6100 | 3270.51] loss=1.97 avg=1.78
# [6200 | 3322.60] loss=1.17 avg=1.76
# [6300 | 3374.72] loss=1.05 avg=1.75
# [6400 | 3426.89] loss=2.11 avg=1.76
# [6500 | 3478.94] loss=1.78 avg=1.76
# [6600 | 3531.18] loss=1.68 avg=1.75
# [6700 | 3583.18] loss=1.89 avg=1.76
# [6800 | 3635.21] loss=1.44 avg=1.75
# [6900 | 3687.31] loss=1.45 avg=1.75
# [7000 | 3739.37] loss=1.71 avg=1.74
# [7100 | 3791.42] loss=1.52 avg=1.74
# [7200 | 3843.49] loss=2.22 avg=1.75
# [7300 | 3895.68] loss=1.29 avg=1.74
# [7400 | 3947.88] loss=1.19 avg=1.73
# [7500 | 4000.08] loss=1.42 avg=1.72
# [7600 | 4052.26] loss=1.94 avg=1.73
# [7700 | 4104.32] loss=1.43 avg=1.72
# [7800 | 4156.37] loss=1.16 avg=1.71
# [7900 | 4208.45] loss=1.43 avg=1.71
# [8000 | 4260.59] loss=1.41 avg=1.70
# Saving checkpoint/QA_m_70k_random/model-8000
# ======== SAMPLE 1 ========
#  ash the "pitch" they are a "pitch"
# [ANSWER]:the "pitch" they cover
# [QUESTION]:How are water lines and plants used?
# [ANSWER]:in water
# [QUESTION]:How can water be accessed in wood?
# [ANSWER]:the "pitch" they cover
# [QUESTION]:How long have water markings been present on the sides of wood?
# [ANSWER]:over time
# <|endoftext|>
# <|startoftext|>
# [CONTEXT]: This may be applied to light, or in other fields such as in farming, as there typically is a tendency to reduce some of the effects of light. For this reason, many plants often use some light to provide the light their roots require, for protection from direct light (dusk or dawn), or for promoting pollination of secondary metabolites in trees by the roots. These plants have special means of maintaining this light, which is essential to the health of these ecosystems. As they move away from the natural light, the plants continue to need some light. The plants are then ready for the lights so they can continue to pollinate.
# [QUESTION]:What plants tend to have a special way to maintain lighting effects?
# [ANSWER]:As they move away from the natural light
# [QUESTION]:What plants use light to provide light?
# [ANSWER]:Light
# [QUESTION]:What is the name of the light used by plants to promote pollination of secondary metabolites in trees?
# [ANSWER]:light
# <|endoftext|>
# <|startoftext|>
# [CONTEXT]: This is an area dominated by wood. As far back as the Mesozoic, trees were often used as ropes or to cover logs.[b] From the late Cambrian period up until the Cretaceous Period and throughout the Late Carboniferous, forests were the dominant source of light in trees and the sun was essential to all aspects of daily life. This changed with the onset of drought in the last Miocene Epoch, and trees found a greater need to use the sun. At the onset of the Cretaceous, trees in Australia, Australia, and all land on Earth would have been using a significant amount of water vapor to regulate the atmosphere and keep the earth's surface warm.[citation needed]
# [QUESTION]:What would trees have used at the Cretaceous period?
# [ANSWER]:a significant amount of water vapor
# [QUESTION]:What kind of activity by trees would have occurred during the CRetaceous ?
# [ANSWER]:drought
# [QUESTION]:What caused a significant change in the nature of trees during the Cretaceous ?
# [ANSWER]:the onset of drought
# [QUESTION]:What would trees in Australia have used in order to keep their plants cool and the atmosphere warm during the Cretaceous Period?
# [ANSWER]:a significant amount of water vapor
# [QUESTION]:In what period was water vapor used by trees in Australia to keep the weather from blowing?
# [ANSWER]:Miocene Epoch,
# <|endoftext|>
# <|startoftext|>
# [CONTEXT]: The late Carboniferous in the United States have had a unique problem with fire and drought, as the vast and rich forests that exist today tend to dry up quickly as sunlight or the earth warms, or as the trees die and fall as the result. This may be due to slow-moving rivers, large disturbances of soil, or heavy rain. Most of the early forests were removed by fires or by erosion, though much later, with the exception of latewoods.[citation needed] In the early Carboniferous forests, forests were not destroyed. Trees continued to grow and to become larger, as rain was not falling.
# [QUESTION]:In which country has had a unique problem with fire and drought ?
# [ANSWER]:the United States
# [QUESTION]:Where did most of the early forests live ?
# [ANSWER]:the Carboniferous forest
# [QUESTION]:In the Carboniferous Forest, what was not the result when trees were removed ?
# [ANSWER]:growth
# [QUESTION]:Why has the American forest been a problem with fire and drought ?
# [ANSWER]:the vast and rich forests
# <|endoftext|>
# <|startoftext|>
# [CONTEXT]: While the majority of soil and topsoil support, there are situations where the soils and topsoil of a region support only part of the root zone. These are best when water accumulation is low and the soil is rich in nutrients. The water evaporates quickly from the surface, preventing the plant from receiving their water back. In these soils, the soil is also weakened so the roots and roots cannot expand into the soil during water retention. To the extent that the roots grow, they are absorbing less
#
# [8100 | 4337.24] loss=1.71 avg=1.70
# [8200 | 4389.20] loss=1.19 avg=1.69
# [8300 | 4441.20] loss=1.46 avg=1.69
# [8400 | 4493.25] loss=1.62 avg=1.69
# [8500 | 4545.26] loss=0.81 avg=1.67
# [8600 | 4597.32] loss=1.17 avg=1.66
# [8700 | 4649.53] loss=1.39 avg=1.66
# [8800 | 4701.66] loss=1.81 avg=1.66
# [8900 | 4753.80] loss=2.12 avg=1.67
# [9000 | 4805.99] loss=1.65 avg=1.67
# [9100 | 4858.13] loss=1.17 avg=1.66
# [9200 | 4910.28] loss=1.59 avg=1.66
# [9300 | 4962.64] loss=1.63 avg=1.66
# [9400 | 5014.84] loss=1.80 avg=1.66
# [9500 | 5067.01] loss=1.21 avg=1.65
# [9600 | 5119.21] loss=1.58 avg=1.65
# [9700 | 5171.39] loss=1.19 avg=1.65
# [9800 | 5223.62] loss=1.92 avg=1.65
# [9900 | 5275.96] loss=1.77 avg=1.65
# [10000 | 5328.19] loss=2.07 avg=1.66
# Saving checkpoint/QA_m_70k_random/model-10000
# ======== SAMPLE 1 ========
# able
# [QUESTION]:What is the definition of "prajkana"?
# [ANSWER]:unanswerable
# [QUESTION]:What does kundalā mean?
# [ANSWER]:purification, purification of living beings
# <|endoftext|>
# <|startoftext|>
# [CONTEXT]: The most familiar of the four basic sutras is the Jyotika (Sanskrit: क्ख्त्षु, cognate with सुगानिप kundal nāsād, "prior knowledge by heart") that deals with the nature of reality and the role of mind. It was initially associated with the doctrine of Brahmāṇins, but later evolved into an influential and even cult-like form of Buddhism. It is said to contain all of the following:
# [QUESTION]:What type of Buddha was the  Jyotika?
# [ANSWER]:Buddhistic
# [QUESTION]:What is Indrajyotika associated with?
# [ANSWER]:the doctrine of Brahmāṇins
# [QUESTION]:What other important sutras are the Jyotika considered to deal with?
# [ANSWER]:unanswerable
# [QUESTION]:What type of sutra is the Jyotika?
# [ANSWER]:unanswerable
# [QUESTION]:What type of sutram is the Jyotika?
# [ANSWER]:unanswerable
# [QUESTION]:What is the  Jyotika?
# [ANSWER]:sanskrit for knowledge of reality and the role of mind
# [QUESTION]:The role of mind of Indrajyotika is what?
# [ANSWER]:unanswerable
# <|endoftext|>
# <|startoftext|>
# [CONTEXT]: The Nāgāka (also known as the Tantric scriptures) are texts that outline the true nature of the Buddha, their subject matter and their function. These texts were commonly understood and used as an aid for aspiring buddhas, offering a model to follow in their quest for liberation. There are four sources of the tantric literature: the Nikaya (discourse), the Mahāsaṅghika, the Vaisnika and the Tantricotakas (compulsory schools).
# [QUESTION]:How many schools are Tantricotakas in the world?
# [ANSWER]:compulsory schools
# [QUESTION]:The Nibbōla or Nāgāka are the source of what?
# [ANSWER]:true nature of the Buddha
# [QUESTION]:How many sources of the Tantric literature are there?
# [ANSWER]:Four
# [QUESTION]:The Nibbōla is the source of what?
# [ANSWER]:unanswerable
# [QUESTION]:The Tantric scriptures are sometimes included if you're working in what?
# [ANSWER]:unanswerable
# [QUESTION]:What type of texts are considered the "true literature of the Buddha"?
# [ANSWER]:The Nāgāka
# <|endoftext|>
# <|startoftext|>
# [CONTEXT]: In the fourth century, Buddhism gradually evolved into a complex system of meditation, meditation practice, sutra analysis, and esoteric cult practices. According to the Vinaya, monks should meditate, meditate regularly, and meditate with concentration, practice and insight. According to the Jnana, devas can assist monks in meditation. The Jnana asserts that buddhas of different schools are united by their common goal of Awakening the samsaric level of society—an internationally agreed-upon goal.
# [QUESTION]:Buddhism had a complex system until what century?
# [ANSWER]:fourth century
# [QUESTION]:At the the end of the seventh century, what did Buddhism evolve into?
# [ANSWER]:a complex system of meditation, meditation practice, sutra analysis, and esoteric cult practices
# [QUESTION]:In what century did Buddhism decline?
# [ANSWER]:unanswerable
# [QUESTION]:What goals are the buddhas in different schools united by?
# [ANSWER]:independently agreed-upon
# [QUESTION]:In which century did Buddhism have an intricate system?
# [ANSWER]:fourth
# [QUESTION]:What was said to be the goal of different schools?
# [ANSWER]:Awakening the samsaric level of society
# [QUESTION]:What type of practice are used in meditation to help learners of the buddhist tradition?
# [ANSWER]:buddha meditation
# [QUESTION]:Buddhism was a complex system until the end of what century?
# [ANSWER]:
#
# [10100 | 5406.00] loss=1.33 avg=1.65
# [10200 | 5458.17] loss=1.14 avg=1.64
# [10300 | 5510.42] loss=1.14 avg=1.64
# [10400 | 5562.74] loss=2.26 avg=1.65
# [10500 | 5614.98] loss=1.39 avg=1.64
# [10600 | 5667.21] loss=1.71 avg=1.64
# [10700 | 5719.46] loss=1.95 avg=1.65
# [10800 | 5771.73] loss=1.62 avg=1.65
# [10900 | 5824.02] loss=1.74 avg=1.65
# [11000 | 5876.39] loss=0.96 avg=1.64
# [11100 | 5928.66] loss=1.55 avg=1.64
# [11200 | 5980.96] loss=1.64 avg=1.64
# [11300 | 6033.27] loss=1.09 avg=1.63
# [11400 | 6085.52] loss=1.48 avg=1.63
# [11500 | 6137.78] loss=1.63 avg=1.63
# [11600 | 6190.14] loss=1.12 avg=1.62
# [11700 | 6242.36] loss=1.50 avg=1.62
# [11800 | 6294.60] loss=1.19 avg=1.61
# [11900 | 6346.85] loss=2.10 avg=1.62
# [12000 | 6399.07] loss=1.32 avg=1.62
# Saving checkpoint/QA_m_70k_random/model-12000
# ======== SAMPLE 1 ========
# . It can be used as a combination of two other similar items or of two different items.
# [QUESTION]:What is the name of the process of the placement of an item in a game?
# [ANSWER]:staging
# [QUESTION]:What is the name of the process of placing an item in a game?
# [ANSWER]:unanswerable
# [QUESTION]:What is one unique and important attribute by itself is not the purpose of the staging?
# [ANSWER]:the items can be used freely in all areas of the game
# [QUESTION]:What is used as a combination of two other similar items?
# [ANSWER]:unanswerable
# [QUESTION]:What is often the sole purpose of staging a game?
# [ANSWER]:unanswerable
# [QUESTION]:In games, you might want to be careful of what?
# [ANSWER]:unanswerable
# [QUESTION]:Why would staging be a way to avoid this?
# [ANSWER]:unanswerable
# [QUESTION]:How do you obtain a game?
# [ANSWER]:A Game Takeover
# [QUESTION]:What can be used freely in all areas of the game.
# [ANSWER]:a game takeover
# [QUESTION]:What can you stage in a game?
# [ANSWER]:items can be used freely in all areas of the game,
# [QUESTION]:What is a way you avoid having to complete a game again?
# [ANSWER]:unanswerable
# [QUESTION]:What is the name of one unique and important characteristic of a game?
# [ANSWER]:unique and important player interactions
# [QUESTION]:What is one method to obtain a game?
# [ANSWER]:Game Takeover
# <|endoftext|>
# <|startoftext|>
# [CONTEXT]: Most computer games require input, usually in the form of an input box. Some, such as Myst and Portal, use a non-input box technique known as the "multi-touch screen". The input boxes in other games also provide simple convenience. Take for example Zelda's mirroring ability, which allows the sword to switch to any sword twice. Others, such as DuckTales, offer simple challenges that reward the player with secret goodies. In side-scrolling games such as Ocarina of Time and The Wind Waker, a large part of the game play is controlling the flow of time.
# [QUESTION]:How many switches on the multitap screen is there in Ocarina of Time?
# [ANSWER]:unanswerable
# [QUESTION]:What does mirroring the Twilight Princess enable?
# [ANSWER]:unanswerable
# [QUESTION]:How many switches is there on the multi-touch screen in Portal?
# [ANSWER]:two
# [QUESTION]:Who uses a multi-touch screen technique called Multi-Touch Screen?
# [ANSWER]:Possible game play involves controlling the flow of time
# [QUESTION]:What is used in puzzles in Ocarina of Time?
# [ANSWER]:unanswerable
# [QUESTION]:How many switches does the sword in Portal switch to?
# [ANSWER]:twice
# [QUESTION]:What is a puzzle in Ocarina of Time about timing?
# [ANSWER]:"Multi-Touch Screen"
# [QUESTION]:What does MirrorFX enable?
# [ANSWER]:unanswerable
# [QUESTION]:What is a simple way the player controls time?
# [ANSWER]:Control the Flow of Time
# [QUESTION]:What games use input and provide simple problems rewarded?
# [ANSWER]:unanswerable
# [QUESTION]:What input box does Ocarina of Time use?
# [ANSWER]:input
# [QUESTION]:What does MirrorFX enable the player to do?
# [ANSWER]:multi-touch screen technique
# <|endoftext|>
# <|startoftext|>
# [CONTEXT]: Unlike other video game consoles in the US, Nintendo maintains a print policy of non-negotiating with publishers in the U.S. The company is the publisher of The Legend of Zelda: The Adventure Card. Nintendo's policy means the company "providing retail sets of a game can choose to print parts or all of the game", whereas the games are "available only on video game packaging, and not in-game packaging". Nintendo's print policy is a move that is in line with its print release policy for other console games in the US and UK. This is because the company has a print-to-video release contract with Nintendo of America that allows the company to reprint the Game Boy Game Boy Advance in the U.S., or the Japanese home video game PlayStation, for use in North and South America, and also to release a reprint game on NES and Sega Mega-CD in various areas of the world. This policy effectively prevents the Japanese
#
# [12100 | 6477.12] loss=1.50 avg=1.61
# [12200 | 6529.44] loss=1.77 avg=1.62
# [12300 | 6581.66] loss=1.11 avg=1.61
# [12400 | 6633.88] loss=1.55 avg=1.61
# [12500 | 6686.20] loss=1.11 avg=1.60
# [12600 | 6738.47] loss=2.37 avg=1.61
# [12700 | 6790.70] loss=2.41 avg=1.62

# %%
# if you want to save the model to you google drive after fine tuning
# gpt2.mount_gdrive()
# gpt2.copy_checkpoint_to_gdrive(run_name='QA_m_30k_random')

# %%
# copy model from drive
# gpt2.copy_checkpoint_from_gdrive(run_name='QA_m_30k_random')

# %%
sess = gpt2.start_tf_sess()
gpt2.load_gpt2(sess, run_name='QA_m_30k_random')
# Out:
# Loading checkpoint checkpoint/QA_m_30k_random/model-30000
# INFO:tensorflow:Restoring parameters from checkpoint/QA_m_30k_random/model-30000

# %%
# f1 score helper function
def normalize_text(s):
    """Removing articles and punctuation, and standardizing whitespace are all typical text processing steps."""
    import string, re

    def remove_articles(text):
        regex = re.compile(r"\b(a|an|the)\b", re.UNICODE)
        return re.sub(regex, " ", text)

    def white_space_fix(text):
        return " ".join(text.split())

    def remove_punc(text):
        exclude = set(string.punctuation)
        return "".join(ch for ch in text if ch not in exclude)

    def lower(text):
        return text.lower()

    return white_space_fix(remove_articles(remove_punc(lower(s))))

def compute_f1(prediction, truth):
    pred_tokens = normalize_text(prediction).split()
    truth_tokens = normalize_text(truth).split()
    
    # if either the prediction or the truth is no-answer then f1 = 1 if they agree, 0 otherwise
    if len(pred_tokens) == 0 or len(truth_tokens) == 0:
        return int(pred_tokens == truth_tokens)
    
    common_tokens = set(pred_tokens) & set(truth_tokens)
    
    # if there are no common tokens then f1 = 0
    if len(common_tokens) == 0:
        return 0
    
    prec = len(common_tokens) / len(pred_tokens)
    rec = len(common_tokens) / len(truth_tokens)
    
    return 2 * (prec * rec) / (prec + rec)

predicted_answer = 'The wetter climate may have allowed for the spread of the rainforest to spread out across the continent.'
true_answer = ['the wetter climate may have allowed the tropical rainforest to spread out across the continent', 'wetter']
f1_score = max((compute_f1(predicted_answer, a)) for a in true_answer)
f1_score
# Out:
# 0.8461538461538461

# %%
# %%time
ems = []
f1s = []
pred_answers = []
start = time()
# for i in range(len(dev_contexts)):
for i in tqdm(range(500)):
  
  if (i+1) % 15 == 0:
    # release memory
    gpt2.reset_session(sess)
    tf.reset_default_graph()
    sess = gpt2.start_tf_sess()
    gpt2.load_gpt2(sess, run_name='QA_m_30k_random')

  pre = c + dev_contexts[i] + q + dev_questions[i] + a
  pre_len = len(pre)
  ans = gpt2.generate(sess,
                length=30,
                temperature=0.5,
                prefix=pre,
                nsamples=1,
                batch_size=1,
                run_name="QA_m_30k_random",
                return_as_list=True)[0]
  # print(time() - start)
  predicted_answer = ans[pre_len:].split('\n')[0]
  pred_answers.append(predicted_answer)
  true_answer = dev_answers[i]
  f1s.append(max((compute_f1(predicted_answer, a)) for a in true_answer))
  # print(time() - start)
  ems.append(predicted_answer in true_answer)
# Out:
#   3%|▎         | 14/500 [02:44<1:48:39, 13.42s/it]
# Loading checkpoint checkpoint/QA_m_30k_random/model-30000
# INFO:tensorflow:Restoring parameters from checkpoint/QA_m_30k_random/model-30000
#   6%|▌         | 29/500 [05:58<1:46:08, 13.52s/it]
# Loading checkpoint checkpoint/QA_m_30k_random/model-30000
# INFO:tensorflow:Restoring parameters from checkpoint/QA_m_30k_random/model-30000
#   9%|▉         | 44/500 [09:08<1:44:01, 13.69s/it]
# Loading checkpoint checkpoint/QA_m_30k_random/model-30000
# INFO:tensorflow:Restoring parameters from checkpoint/QA_m_30k_random/model-30000
#  12%|█▏        | 59/500 [12:11<1:38:14, 13.37s/it]
# Loading checkpoint checkpoint/QA_m_30k_random/model-30000
# INFO:tensorflow:Restoring parameters from checkpoint/QA_m_30k_random/model-30000
#  15%|█▍        | 74/500 [15:14<1:35:23, 13.44s/it]
# Loading checkpoint checkpoint/QA_m_30k_random/model-30000
# INFO:tensorflow:Restoring parameters from checkpoint/QA_m_30k_random/model-30000
#  18%|█▊        | 89/500 [18:18<1:31:31, 13.36s/it]
# Loading checkpoint checkpoint/QA_m_30k_random/model-30000
# INFO:tensorflow:Restoring parameters from checkpoint/QA_m_30k_random/model-30000
#  21%|██        | 104/500 [21:18<1:27:00, 13.18s/it]
# Loading checkpoint checkpoint/QA_m_30k_random/model-30000
# INFO:tensorflow:Restoring parameters from checkpoint/QA_m_30k_random/model-30000
#  24%|██▍       | 119/500 [24:20<1:23:49, 13.20s/it]
# Loading checkpoint checkpoint/QA_m_30k_random/model-30000
# INFO:tensorflow:Restoring parameters from checkpoint/QA_m_30k_random/model-30000
#  27%|██▋       | 134/500 [27:24<1:22:57, 13.60s/it]
# Loading checkpoint checkpoint/QA_m_30k_random/model-30000
# INFO:tensorflow:Restoring parameters from checkpoint/QA_m_30k_random/model-30000
#  30%|██▉       | 149/500 [30:31<1:19:12, 13.54s/it]
# Loading checkpoint checkpoint/QA_m_30k_random/model-30000
# INFO:tensorflow:Restoring parameters from checkpoint/QA_m_30k_random/model-30000
#  33%|███▎      | 164/500 [33:37<1:16:05, 13.59s/it]
# Loading checkpoint checkpoint/QA_m_30k_random/model-30000
# INFO:tensorflow:Restoring parameters from checkpoint/QA_m_30k_random/model-30000
#  36%|███▌      | 179/500 [36:43<1:13:23, 13.72s/it]
# Loading checkpoint checkpoint/QA_m_30k_random/model-30000
# INFO:tensorflow:Restoring parameters from checkpoint/QA_m_30k_random/model-30000
#  39%|███▉      | 194/500 [39:50<1:09:10, 13.56s/it]
# Loading checkpoint checkpoint/QA_m_30k_random/model-30000
# INFO:tensorflow:Restoring parameters from checkpoint/QA_m_30k_random/model-30000
#  42%|████▏     | 209/500 [42:55<1:05:38, 13.53s/it]
# Loading checkpoint checkpoint/QA_m_30k_random/model-30000
# INFO:tensorflow:Restoring parameters from checkpoint/QA_m_30k_random/model-30000
#  45%|████▍     | 224/500 [46:01<1:03:19, 13.77s/it]
# Loading checkpoint checkpoint/QA_m_30k_random/model-30000
# INFO:tensorflow:Restoring parameters from checkpoint/QA_m_30k_random/model-30000
#  48%|████▊     | 239/500 [49:11<1:00:13, 13.85s/it]
# Loading checkpoint checkpoint/QA_m_30k_random/model-30000
# INFO:tensorflow:Restoring parameters from checkpoint/QA_m_30k_random/model-30000
#  51%|█████     | 254/500 [52:18<55:44, 13.59s/it]
# Loading checkpoint checkpoint/QA_m_30k_random/model-30000
# INFO:tensorflow:Restoring parameters from checkpoint/QA_m_30k_random/model-30000
#  54%|█████▍    | 269/500 [55:22<51:39, 13.42s/it]
# Loading checkpoint checkpoint/QA_m_30k_random/model-30000
# INFO:tensorflow:Restoring parameters from checkpoint/QA_m_30k_random/model-30000
#  57%|█████▋    | 284/500 [58:24<47:33, 13.21s/it]
# Loading checkpoint checkpoint/QA_m_30k_random/model-30000
# INFO:tensorflow:Restoring parameters from checkpoint/QA_m_30k_random/model-30000
#  60%|█████▉    | 299/500 [1:01:23<43:53, 13.10s/it]
# Loading checkpoint checkpoint/QA_m_30k_random/model-30000
# INFO:tensorflow:Restoring parameters from checkpoint/QA_m_30k_random/model-30000
#  63%|██████▎   | 314/500 [1:04:28<43:00, 13.88s/it]
# Loading checkpoint checkpoint/QA_m_30k_random/model-30000
# INFO:tensorflow:Restoring parameters from checkpoint/QA_m_30k_random/model-30000
#  66%|██████▌   | 329/500 [1:07:39<39:30, 13.86s/it]
# Loading checkpoint checkpoint/QA_m_30k_random/model-30000
# INFO:tensorflow:Restoring parameters from checkpoint/QA_m_30k_random/model-30000
#  69%|██████▉   | 344/500 [1:10:44<34:54, 13.43s/it]
# Loading checkpoint checkpoint/QA_m_30k_random/model-30000
# INFO:tensorflow:Restoring parameters from checkpoint/QA_m_30k_random/model-30000
#  72%|███████▏  | 359/500 [1:13:45<31:07, 13.25s/it]
# Loading checkpoint checkpoint/QA_m_30k_random/model-30000
# INFO:tensorflow:Restoring parameters from checkpoint/QA_m_30k_random/model-30000
#  75%|███████▍  | 374/500 [1:16:50<28:05, 13.37s/it]
# Loading checkpoint checkpoint/QA_m_30k_random/model-30000
# INFO:tensorflow:Restoring parameters from checkpoint/QA_m_30k_random/model-30000
#  78%|███████▊  | 389/500 [1:19:50<24:31, 13.25s/it]
# Loading checkpoint checkpoint/QA_m_30k_random/model-30000
# INFO:tensorflow:Restoring parameters from checkpoint/QA_m_30k_random/model-30000
#  81%|████████  | 404/500 [1:22:52<21:11, 13.25s/it]
# Loading checkpoint checkpoint/QA_m_30k_random/model-30000
# INFO:tensorflow:Restoring parameters from checkpoint/QA_m_30k_random/model-30000
#  84%|████████▍ | 419/500 [1:26:02<18:54, 14.01s/it]
# Loading checkpoint checkpoint/QA_m_30k_random/model-30000
# INFO:tensorflow:Restoring parameters from checkpoint/QA_m_30k_random/model-30000
#  87%|████████▋ | 434/500 [1:29:13<15:21, 13.96s/it]
# Loading checkpoint checkpoint/QA_m_30k_random/model-30000
# INFO:tensorflow:Restoring parameters from checkpoint/QA_m_30k_random/model-30000
#  90%|████████▉ | 449/500 [1:32:21<11:37, 13.68s/it]
# Loading checkpoint checkpoint/QA_m_30k_random/model-30000
# INFO:tensorflow:Restoring parameters from checkpoint/QA_m_30k_random/model-30000
#  93%|█████████▎| 464/500 [1:35:24<08:06, 13.52s/it]
# Loading checkpoint checkpoint/QA_m_30k_random/model-30000
# INFO:tensorflow:Restoring parameters from checkpoint/QA_m_30k_random/model-30000
#  96%|█████████▌| 479/500 [1:38:33<04:49, 13.76s/it]
# Loading checkpoint checkpoint/QA_m_30k_random/model-30000
# INFO:tensorflow:Restoring parameters from checkpoint/QA_m_30k_random/model-30000
#  99%|█████████▉| 494/500 [1:41:39<01:21, 13.50s/it]
# Loading checkpoint checkpoint/QA_m_30k_random/model-30000
# INFO:tensorflow:Restoring parameters from checkpoint/QA_m_30k_random/model-30000
# 100%|██████████| 500/500 [1:42:47<00:00, 12.34s/it]
# CPU times: user 1h 43min 3s, sys: 1min 6s, total: 1h 44min 9s
# Wall time: 1h 42min 47s

# %%
np.mean(f1s)
# Out:
# 0.576591330891331

# %%
np.mean(ems)
# Out:
# 0.508
